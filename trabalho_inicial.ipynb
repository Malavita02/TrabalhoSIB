# %%
import numpy as np
import pandas as pd

pheno_train = pd.read_csv(r"C:\Users\Tiago\Desktop\Aulas 2 ano\SIB\trabalho_pratico\DreamHF\train\pheno_training.csv")
readcounts_train = pd.read_csv(r"C:\Users\Tiago\Desktop\Aulas 2 ano\SIB\trabalho_pratico\DreamHF\train\readcounts_training.csv")
taxtable_train = pd.read_csv(r"C:\Users\Tiago\Desktop\Aulas 2 ano\SIB\trabalho_pratico\DreamHF\train\taxtable.csv")

# %% [markdown]
# ## Exploração inicial
# #### pheno_train

# %%
pheno_train.dtypes
# Out:
# Unnamed: 0            object
# Age                  float64
# BodyMassIndex        float64
# Smoking              float64
# BPTreatment            int64
# PrevalentDiabetes    float64
# PrevalentCHD         float64
# PrevalentHFAIL       float64
# Event                float64
# Event_time           float64
# SystolicBP           float64
# NonHDLcholesterol    float64
# Sex                    int64
# dtype: object

# %%
pheno_train.describe()
# Out:
#                Age  BodyMassIndex      Smoking  BPTreatment  \
# count  3615.000000    3614.000000  3599.000000  3615.000000
# mean     49.504423      27.071102     0.232842     0.155463
# std      14.848086       4.724096     0.422701     0.362396
# min      24.098000      15.839000     0.000000     0.000000
# 25%      36.808500      23.774250     0.000000     0.000000
# 50%      50.909000      26.402000     0.000000     0.000000
# 75%      61.759000      29.499750     0.000000     0.000000
# max      74.242000      56.935000     1.000000     1.000000
#
#        PrevalentDiabetes  PrevalentCHD  PrevalentHFAIL        Event  \
# count        3564.000000   3564.000000     3564.000000  3564.000000
# mean            0.061728      0.032828        0.026094     0.084175
# std             0.240695      0.178212        0.159438     0.277689
# min             0.000000      0.000000        0.000000     0.000000
# 25%             0.000000      0.000000        0.000000     0.000000
# ...

# %%
pheno_train_female = pheno_train[pheno_train["Sex"] == 0]
pheno_train_female
# Out:
#           Unnamed: 0     Age  BodyMassIndex  Smoking  BPTreatment  \
# 0      Simulated_328  53.618         24.127      0.0            0
# 1     Simulated_1644  36.811         27.992      0.0            0
# 3     Simulated_1732  48.842         26.804      0.0            0
# 6     Simulated_1681  60.941         34.778      0.0            0
# 8     Simulated_1603  62.498         27.583      0.0            0
# ...              ...     ...            ...      ...          ...
# 3607  Simulated_1605  74.091         30.560      0.0            0
# 3608  Simulated_2202  74.129         27.480      0.0            1
# 3610  Simulated_1783  33.802         37.049      0.0            0
# 3613  Simulated_1592  70.278         31.945      0.0            1
# 3614  Simulated_1731  38.799         25.928      0.0            0
#
#       PrevalentDiabetes  PrevalentCHD  PrevalentHFAIL  Event  Event_time  \
# 0                   0.0           0.0             0.0    0.0      15.750
# ...

# %%
pheno_train_nonaa = pheno_train.dropna()
pheno_train_nonaa.describe()
# Out:
#                Age  BodyMassIndex      Smoking  BPTreatment  \
# count  3540.000000    3540.000000  3540.000000  3540.000000
# mean     49.516436      27.075270     0.234746     0.155650
# std      14.867448       4.724706     0.423900     0.362574
# min      24.098000      15.839000     0.000000     0.000000
# 25%      36.800750      23.782500     0.000000     0.000000
# 50%      50.854500      26.405000     0.000000     0.000000
# 75%      61.776250      29.498250     0.000000     0.000000
# max      74.242000      56.935000     1.000000     1.000000
#
#        PrevalentDiabetes  PrevalentCHD  PrevalentHFAIL        Event  \
# count        3540.000000   3540.000000     3540.000000  3540.000000
# mean            0.062147      0.033051        0.025989     0.084181
# std             0.241456      0.178795        0.159124     0.277698
# min             0.000000      0.000000        0.000000     0.000000
# 25%             0.000000      0.000000        0.000000     0.000000
# ...

# %% [markdown]
# #### Exploração readcounts_train

# %%
readcounts_train.dtypes
# Out:
# Unnamed: 0        object
# Simulated_328      int64
# Simulated_1644     int64
# Simulated_1710     int64
# Simulated_1732     int64
#                    ...
# Simulated_1783     int64
# Simulated_3425     int64
# Simulated_1789     int64
# Simulated_1592     int64
# Simulated_1731     int64
# Length: 3616, dtype: object

# %%
readcounts_train.describe()
# Out:
#        Simulated_328  Simulated_1644  Simulated_1710  Simulated_1732  \
# count    5748.000000     5748.000000     5748.000000     5748.000000
# mean      187.729819      201.291232      129.467989      273.373695
# std      4045.491449     7845.598753     4853.530742     5765.579549
# min         0.000000        0.000000        0.000000        0.000000
# 25%         0.000000        0.000000        0.000000        0.000000
# 50%         0.000000        0.000000        0.000000        0.000000
# 75%         2.000000        0.000000        1.000000        2.000000
# max    276290.000000   469820.000000   359562.000000   279370.000000
#
#        Simulated_1727  Simulated_2196  Simulated_1681  Simulated_1651  \
# count     5748.000000     5748.000000     5748.000000     5748.000000
# mean       116.749130      132.382220       55.174843       87.517223
# std       1893.994589     1971.111151     1275.434827     1724.518096
# ...

# %%
readcounts_train["Unnamed: 0"]
# Out:
# 0                      k__Archaea;p__;c__;o__;f__;g__;s__
# 1       k__Archaea;p__Candidatus_Korarchaeota;c__;o__;...
# 2       k__Archaea;p__Crenarchaeota;c__Thermoprotei;o_...
# 3       k__Archaea;p__Crenarchaeota;c__Thermoprotei;o_...
# 4       k__Archaea;p__Crenarchaeota;c__Thermoprotei;o_...
#                               ...
# 5743    k__Viruses;p__unclassified_bacterial_viruses;c...
# 5744    k__Viruses;p__unclassified_viruses;c__Leptopil...
# 5745    k__Viruses;p__unclassified_viruses;c__Mollivir...
# 5746    k__Viruses;p__unclassified_viruses;c__Smacovir...
# 5747    k__Viruses;p__unclassified_viruses;c__Torulasp...
# Name: Unnamed: 0, Length: 5748, dtype: object

# %%
readcounts_train.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Exploração tasxtable_train

# %%
taxtable_train.head()
# Out:
#        Domain                      Phylum            Class            Order  \
# 0  k__Archaea                         p__              c__              o__
# 1  k__Archaea  p__Candidatus_Korarchaeota              c__              o__
# 2  k__Archaea            p__Crenarchaeota  c__Thermoprotei              o__
# 3  k__Archaea            p__Crenarchaeota  c__Thermoprotei  o__Acidilobales
# 4  k__Archaea            p__Crenarchaeota  c__Thermoprotei  o__Acidilobales
#
#                 Family            Genus                       Species
# 0                  f__              g__                           s__
# 1                  f__              g__                           s__
# 2                  f__              g__                           s__
# 3     f__Acidilobaceae    g__Acidilobus  s__Acidilobus_saccharovorans
# 4  f__Caldisphaeraceae  g__Caldisphaera    s__Caldisphaera_lagunensis

# %%
taxtable_train_nonan = taxtable_train.dropna()
taxtable_train_nonan.describe()
# Out:
#              Domain             Phylum              Class          Order  \
# count          5713               5713               5713           5713
# unique            5                 50                130            171
# top     k__Bacteria  p__Proteobacteria  c__Actinobacteria  o__Bacillales
# freq           5024               2215                916            391
#
#                       Family Genus Species
# count                   5713  5713    5713
# unique                   364  1471    4535
# top     f__Flavobacteriaceae   g__     s__
# freq                     196   321     845

# %%
taxtable_train.dtypes
# Out:
# Domain     object
# Phylum     object
# Class      object
# Order      object
# Family     object
# Genus      object
# Species    object
# dtype: object
